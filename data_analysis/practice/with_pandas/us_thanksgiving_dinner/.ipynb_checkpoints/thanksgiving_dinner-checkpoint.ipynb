# %%
import pandas as pd

data = pd.read_csv('thanksgiving-data.csv', encoding='Latin-1')
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
# only getting the data from the people who celebrate Thanksgiving

data = data[data['Do you celebrate Thanksgiving?'] == 'Yes']

# %%
# Visualize what people eat in Thanksgiving

what_is_eatten = data['What is typically the main dish at your Thanksgiving dinner?']
print(what_is_eatten.value_counts())
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
eat_tofurkey = data[what_is_eatten == 'Tofurkey']
eat_tofurkey['Do you typically have gravy?']
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
# Visualize all the people who eat apple, pumpkin, or pecan as dessert
apple_null = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'].isnull()
pumpkin_null = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin']
pecan_null = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan']

no_pies = data[apple_null & pumpkin_null & pecan_null]
print(no_pies)

#128 people do not eat any pies for Thanksgiving
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 3       4337933040                            Yes
# 14      4337878351                            Yes
# 24      4337792130                            Yes
# 36      4337758789                            Yes
# 42      4337719588                            Yes
# 48      4337653684                            Yes
# 51      4337629524                            Yes
# 53      4337626849                            Yes
# 54      4337611941                            Yes
# 64      4337577784                            Yes
# 85      4337448181                            Yes
# 101     4337390728                            Yes
# 104     4337382350                            Yes
# 106     4337369789                            Yes
# 130     4337284552                            Yes
# 132     4337262725                            Yes
# 133     4337256857                            Yes
# 135     4337247953                            Yes
# ...

# %%
# More information about the age
import re
def change_age_to_int(single_val):
    p = re.compile('[0-9]+')
    m = p.findall(str(single_val))
    if not m:
        result = None
    else:   
        result = int(m[0])
    return result

data['int_age'] = data['Age'].apply(change_age_to_int)
        
print(data['int_age'].describe())
# Out:
# count    947.000000
# mean      40.089757
# std       15.352014
# min       18.000000
# 25%       30.000000
# 50%       45.000000
# 75%       60.000000
# max       60.000000
# Name: int_age, dtype: float64

# %% [markdown]
# # Have to wirte more about the foundings

# %%
# More information about the income

def change_income_to_int(input_str):
    p = re.compile('[0-9,]+')
    m = p.findall(str(input_str))
    if not m:
        result = None
    else:
        if ',' in m[0]:
            m[0] = m[0].replace(',','')
        result = int(m[0])
    return result

data['int_income'] = data['How much total combined money did all members of your HOUSEHOLD earn last year?']\
.apply(change_income_to_int)

data['int_income'].describe()
# Out:
# count       829.000000
# mean      75965.018094
# std       59068.636748
# min           0.000000
# 25%       25000.000000
# 50%       75000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %% [markdown]
# # More info

# %%
# Distance of travling and income

less_than_150000 = data[data['int_income'] <= 150000]
print(less_than_150000['How far will you travel for Thanksgiving?'].value_counts())

more_than_150000 = data[data['int_income'] > 150000]
print(more_than_150000['How far will you travel for Thanksgiving?'].value_counts())
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         298
# Thanksgiving is local--it will take place in the town I live in                     212
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    159
# Thanksgiving is out of town and far away--I have to drive several hours or fly       58
# Name: How far will you travel for Thanksgiving?, dtype: int64
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
data['int_age']
# Out:
# 0       18.0
# 1       18.0
# 2       18.0
# 3       30.0
# 4       30.0
# 5       18.0
# 6       18.0
# 7       18.0
# 8       30.0
# 9       30.0
# 11      30.0
# 12      18.0
# 13      18.0
# 14      60.0
# 15      30.0
# 16      30.0
# 17      18.0
# 18      30.0
# 19      30.0
# 20      30.0
# 21      18.0
# 23      18.0
# 24      30.0
# 25      18.0
# 26      30.0
# 27      18.0
# 28      30.0
# 29      30.0
# 30      30.0
# 32      18.0
#         ...
# 1024    45.0
# 1025    60.0
# 1026    45.0
# 1027    60.0
# 1029    60.0
# 1030    45.0
# 1031    45.0
# 1033    30.0
# 1034    30.0
# 1035    30.0
# 1037    30.0
# 1038    60.0
# 1039    18.0
# 1040    30.0
# 1041    45.0
# 1042    45.0
# 1043    45.0
# 1044    60.0
# 1045    30.0
# 1046    18.0
# 1047    30.0
# 1048    60.0
# 1049     NaN
# 1050    60.0
# 1051    60.0
# 1053    30.0
# 1054    60.0
# 1055    60.0
# 1056     NaN
# 1057     NaN
# Name: int_age, Length: 980, dtype: float64

# %%
import numpy as np
data.pivot_table(index= ['Have you ever tried to meet up with hometown friends on Thanksgiving night?', 'Have you ever attended a "Friendsgiving?"'], 
                 values='int_age', aggfunc=np.mean)
# Out:
#                                                                                                 int_age
# Have you ever tried to meet up with hometown fr... Have you ever attended a "Friendsgiving?"
# No                                                 No                                         42.283702
#                                                    Yes                                        37.010526
# Yes                                                No                                         41.475410
#                                                    Yes                                        33.976744

# %% [markdown]
# That's it for the guided steps! We recommend exploring the data more on your own.
#
# Here are some potential next steps:
#
# Figure out the most common dessert people eat.
# Figure out the most common complete meal people eat.
# Identify how many people work on Thanksgiving.
# Find regional patterns in the dinner menus.
# Find age, gender, and income based patterns in dinner menus.
# We recommend creating a Github repository and placing this project there. It will help other people, including employers, see your work. As you start to put multiple projects on Github, you'll have the beginnings of a strong portfolio. You're welcome to keep working on the project here, but we recommend downloading it to your computer using the download icon above and working on it there.
